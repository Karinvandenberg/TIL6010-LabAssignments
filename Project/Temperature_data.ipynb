# %%
import pandas as pd

import plotly.express as px

# %%
file_path = 'Rawdata_temperature/Temperature_data.csv'

# %%
df_temperature_data = pd.read_csv(file_path, delimiter=',', skiprows=[0,1,2,3]) #read csv and skip first 4 rows with non usable data
df_temperature_data
# Out:
#        Year  Value
# 0    198701  -3.78
# 1    198702  -0.01
# 2    198703  -2.99
# 3    198704  -0.25
# 4    198705  -0.87
# ..      ...    ...
# 423  202204   0.79
# 424  202205   1.40
# 425  202206   2.52
# 426  202207   1.90
# 427  202208   2.82
#
# [428 rows x 2 columns]

# %%
df_temperature_data['Year'] = pd.to_datetime(df_temperature_data_original['Year'], format='%Y%m') #date from YYYYMM to YYYY-MM-DD
df_temperature_data
# Out:
#           Year  Value
# 0   1987-01-01  -3.78
# 1   1987-02-01  -0.01
# 2   1987-03-01  -2.99
# 3   1987-04-01  -0.25
# 4   1987-05-01  -0.87
# ..         ...    ...
# 423 2022-04-01   0.79
# 424 2022-05-01   1.40
# 425 2022-06-01   2.52
# 426 2022-07-01   1.90
# 427 2022-08-01   2.82
#
# [428 rows x 2 columns]

# %%
fig = px.line(df_temperature_data, x="Year", y="Value", title='Surface temperature anomalies'
             )
fig.show()
